# %%
from Bio import SeqIO
from Bio import AlignIO
from Bio import Phylo
import pandas as pd

# %%
list_fasta = list(SeqIO.parse("df1.fasta", "fasta"))

# %%
with open("bugstuff.aln", "r") as aln:
    alignment = AlignIO.read(aln, "clustal")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/1175865844.py in <module>
# ----> 1 with open("bugstuff.aln", "r") as aln:
#       2     alignment = AlignIO.read(aln, "clustal")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bugstuff.aln'

# %%
print(type(alignment))

# %%
from Bio.Phylo.TreeConstruction import DistanceCalculator
calculator = DistanceCalculator('identity')

# %%
distance_matrix = calculator.get_distance(alignment)

# %%
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor(calculator)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/2722737543.py in <module>
#       1 from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
# ----> 2 constructor = DistanceTreeConstructor(calculator)
#
# NameError: name 'calculator' is not defined

# %%
bug_tree = constructor.build_tree(alignment)
bug_tree.rooted = True
print(bug_tree)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/2638985642.py in <module>
# ----> 1 bug_tree = constructor.build_tree(alignment)
#       2 bug_tree.rooted = True
#       3 print(bug_tree)
#
# NameError: name 'constructor' is not defined

# %%
Phylo.write(bug_tree, "bug_tree.xml", "phyloxml")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/3421931942.py in <module>
# ----> 1 Phylo.write(bug_tree, "bug_tree.xml", "phyloxml")
#
# NameError: name 'bug_tree' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
fig = Phylo.draw(bug_tree)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/3241099570.py in <module>
#       1 import matplotlib
#       2 import matplotlib.pyplot as plt
# ----> 3 fig = Phylo.draw(bug_tree)
#
# NameError: name 'bug_tree' is not defined

# %%
fig = plt.figure(figsize=(20, 40), dpi=100) # create figure & set the size 
matplotlib.rc('font', size=6)              # fontsize of the leaf and node labels 
matplotlib.rc('xtick', labelsize=10)       # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=10)       # fontsize of the tick labels
#bug_tree.ladderize()
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(bug_tree, axes=axes)
fig.savefig("bug_cladogram")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tb/9l3h61qj43v8yk_7v3crs4ww0000gn/T/ipykernel_3439/705717783.py in <module>
#       5 #bug_tree.ladderize()
#       6 axes = fig.add_subplot(1, 1, 1)
# ----> 7 Phylo.draw(bug_tree, axes=axes)
#       8 fig.savefig("bug_cladogram")
#
# NameError: name 'bug_tree' is not defined

# %%
Phylo.convert("bug_tree.xml", "phyloxml", "bug_tree.nex", "nexus")
# Out:
# 1

# %%
bug_nex = Phylo.read("bug_edited.nex", "nexus")

fig = plt.figure(figsize=(13, 5), dpi=100) # create figure & set the size 
matplotlib.rc('font', size=12)              # fontsize of the leaf and node labels 
matplotlib.rc('xtick', labelsize=10)       # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=10)       # fontsize of the tick labels
#bug_tree.ladderize()
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(bug_nex, axes=axes)
fig.savefig("bug2_cladogram")
